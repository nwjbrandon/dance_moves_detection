# %%
# !gdown --id 1wZbkmhRZxfaAyqNwXRyRJ-ohMORcX0xf
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1wZbkmhRZxfaAyqNwXRyRJ-ohMORcX0xf
# To: /content/prelim_dataset.csv
# 3.34MB [00:00, 29.5MB/s]

# %%
import os
import re
import itertools
import warnings

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from scipy import stats, signal
from sklearn.manifold import TSNE
from sklearn.metrics import accuracy_score, confusion_matrix, f1_score
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn import preprocessing
from sklearn.model_selection import GridSearchCV, train_test_split, cross_val_score
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.model_selection import KFold

import torch
import torchvision
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

warnings.filterwarnings("ignore")
random_state = 42
activities = ["elbow_lock", "hair", "pushback", "rocket", "scarecrow", "shouldershrug", "windows", "zigzag", "logout"]

# %%
def load_dataset(file_name, columns):
    df = pd.read_csv(file_name, header=None)
    df.columns = ["yaw", "pitch", "acc_x", "acc_y", "acc_z", "activityName"]
    df["activity"] = df["activityName"].replace(activities, [0,1,2,3,4,5,6,7,8])
    return df

file_name="prelim_dataset.csv"
columns = ["yaw", "pitch", "acc_x", "acc_y", "acc_z", "activityName"]
df = load_dataset(file_name, columns)
df.sample()
# Out:
#           yaw  pitch   acc_x   acc_y  acc_z activityName  activity
# 22317  111.56  97.27  0.1124 -0.0383  0.195     pushback         2

# %%
test_df = df[:10]
test_df.head()
test_df["activity"].unique()[0]
# Out:
# 1

# %%
def convert_to_timeseries(features, num_time_steps, num_features):
    data = np.reshape(features, newshape=(num_time_steps, num_features))
    return data.T

X = list()
y = list()
df_len = len(df)
for idx in range(0, df_len, 30):
    window_df = df[idx:idx+60]
    labels = window_df["activity"].unique()
    if len(labels) != 1 or len(window_df) < 60:
        continue
    assert len(labels) == 1 and len(window_df) == 60
    features = window_df.drop(columns=["activity", "activityName"]).values
    features = convert_to_timeseries(features, num_time_steps=60, num_features=5)
    X.append(features)
    y.append(labels)

X = np.array(X)
y = np.array(y)

X.shape, y.shape
# Out:
# ((2467, 5, 60), (2467, 1))

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=random_state)
X_valid, X_test, y_valid, y_test = train_test_split(X_test, y_test, test_size=0.5, random_state=random_state)

# %%
def plot_confusion_matrix(cm, classes, normalize=False, title='Confusion Matrix'):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    plt.figure(figsize=(15,8))
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        cmap='Reds'
        print("Normalized Confusion Matrix")
    else:
        cmap='Greens'
        print('Confusion Matrix Without Normalization')

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=90)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.show()

# %%
class EarlyStopping:
    """Early stops the training if validation loss doesn't improve after a given patience."""
    def __init__(self, patience=7, verbose=False, delta=0):
        """
        Args:
            patience (int): How long to wait after last time validation loss improved.
                            上次验证集损失值改善后等待几个epoch
                            Default: 7
            verbose (bool): If True, prints a message for each validation loss improvement.
                            如果是True，为每个验证集损失值改善打印一条信息
                            Default: False
            delta (float): Minimum change in the monitored quantity to qualify as an improvement.
                            监测数量的最小变化，以符合改进的要求
                            Default: 0
        """
        self.patience = patience
        self.verbose = verbose
        self.counter = 0
        self.best_score = None
        self.early_stop = False
        self.val_loss_min = np.Inf
        self.delta = delta

    def __call__(self, val_loss, model):

        score = -val_loss

        if self.best_score is None:
            self.best_score = score
            self.save_checkpoint(val_loss, model)
        elif score < self.best_score + self.delta:
            self.counter += 1
            print(f'EarlyStopping counter: {self.counter} out of {self.patience}')
            if self.counter >= self.patience:
                self.early_stop = True
        else:
            self.best_score = score
            self.save_checkpoint(val_loss, model)
            self.counter = 0

    def save_checkpoint(self, val_loss, model):
        '''
        Saves model when validation loss decrease.
        验证损失减少时保存模型。
        '''
        if self.verbose:
            print(f'Validation loss decreased ({self.val_loss_min:.6f} --> {val_loss:.6f}).  Saving model ...')
        torch.save(model, 'finish_model.pkl')                 # 这里会存储迄今最优的模型
        self.val_loss_min = val_loss

def plot_avg_loss_per_epoch(avg_train_losses, avg_valid_losses):
    # visualize the loss as the network trained
    fig = plt.figure(figsize=(10,8))
    plt.plot(range(1,len(avg_train_losses)+1), avg_train_losses, label='Training Loss')
    plt.plot(range(1,len(avg_valid_losses)+1), avg_valid_losses,label='Validation Loss')

    # find position of lowest validation loss
    minposs = avg_train_losses.index(min(avg_train_losses))+1 
    plt.axvline(minposs, linestyle='--', color='r',label='Early Stopping Checkpoint')

    plt.xlabel('epochs')
    plt.ylabel('loss')
    plt.ylim(0, 2) # consistent scale
    plt.xlim(0, len(avg_train_losses)+1) # consistent scale
    plt.grid(True)
    plt.legend()
    plt.tight_layout()
    plt.show()

def plot_accuracy_per_epoch(train_accuracies, valid_accuracies):
    # visualize the loss as the network trained
    fig = plt.figure(figsize=(10,8))
    plt.plot(range(1,len(train_accuracies)+1), train_accuracies, label='Train Accuracy')
    plt.plot(range(1,len(valid_accuracies)+1), valid_accuracies,label='Valid Accuracy')

    plt.xlabel('epochs')
    plt.ylabel('accuracy')
    plt.ylim(0, 1) # consistent scale
    plt.xlim(0, len(train_accuracies)+1) # consistent scale
    plt.grid(True)
    plt.legend()
    plt.tight_layout()
    plt.show()

# %%
class DLTrainer:
    def __init__(self, model, trainloader, validloader, testloader, criterion, optimizer, early_stopping, n_epochs, patience, is_time_series=False):
        self.model = model
        self.trainloader = trainloader
        self.validloader = validloader
        self.testloader = testloader
        
        self.criterion = criterion
        self.optimizer = optimizer
        self.early_stopping = early_stopping
        self.n_epochs = n_epochs
        self.patience = patience
        self.is_time_series = is_time_series

        self.avg_train_losses = []
        self.avg_valid_losses = [] 
        self.train_accuracies = []
        self.valid_accuracies = []

    def train(self):
        self.model.cuda()
        for epoch in range(self.n_epochs):  # loop over the dataset multiple times
            train_correct, train_total, train_loss = self.train_epoch()
            valid_correct, valid_total, valid_loss = self.validate_epoch()

            # calculate average loss over an epoch
            train_accuracy = train_correct / train_total
            valid_accuracy = valid_correct / valid_total

            self.avg_train_losses.append(train_loss)
            self.avg_valid_losses.append(valid_loss)
            self.train_accuracies.append(train_accuracy)
            self.valid_accuracies.append(valid_accuracy)

            log_message = f'[{str(epoch)}/{str(self.n_epochs)}] train_loss: {train_loss:.5f} valid_loss: {valid_loss:.5f} train_accuracy: {train_accuracy:.5f} valid_accuracy: {valid_accuracy:.5f}'
            print(log_message)

            self.early_stopping(valid_loss, self.model)
            
            if self.early_stopping.early_stop:
                break

    def train_epoch(self):
        correct = 0
        total = 0
        losses = []

        self.model.train()
        for data in self.trainloader:
            inputs, labels = data

            # if self.is_time_series:
            #     inputs = inputs.permute(0, 2, 1)

            inputs = inputs.to("cuda")
            labels = labels.to("cuda")

            self.optimizer.zero_grad()

            outputs = self.model(inputs.float())

            loss = self.criterion(outputs, labels)
            loss.backward()
            self.optimizer.step()

            losses.append(loss.item())

            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

        return correct, total, np.mean(losses)

    def validate_epoch(self):
        correct = 0
        total = 0
        losses = []

        self.model.eval()
        for data in validloader:
            inputs, labels = data

            # if self.is_time_series:
            #     inputs = inputs.permute(0, 2, 1)

            inputs = inputs.to("cuda")
            labels = labels.to("cuda")

            outputs = self.model(inputs.float())
            loss = self.criterion(outputs, labels)
            losses.append(loss.item())

            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

        return correct, total, np.mean(losses)

    def evaluate(self, dataloader):
        correct = 0
        total = 0
        actual = []
        expected = []

        with torch.no_grad():
            for data in dataloader:
                inputs, labels = data

                # if self.is_time_series:
                #     inputs = inputs.permute(0, 2, 1)

                inputs = inputs.to("cuda")
                labels = labels.to("cuda")
                outputs = self.model(inputs.float())
                _, predicted = torch.max(outputs.data, 1)
                total += labels.size(0)
                correct += (predicted == labels).sum().item()
                expected += labels.cpu()
                actual += predicted.cpu()

        return correct/total, (expected, actual)

    def show_evaluation(self):
        return self.avg_train_losses, self.avg_valid_losses, self.train_accuracies, self.valid_accuracies

# %%
scaler = preprocessing.StandardScaler()
# https://stackoverflow.com/questions/53870113/using-standardscaler-on-3d-data
def scale_data(data, is_train=False):
    num_instances, num_time_steps, num_features = data.shape
    data = np.reshape(data, newshape=(-1, num_features))
    if is_train:
        data = scaler.fit_transform(data)
    else:
        data = scaler.transform(data)
    data = np.reshape(data, newshape=(num_instances, num_time_steps, num_features))
    return data

X_train = scale_data(X_train, is_train=True)
X_valid = scale_data(X_valid)
X_test = scale_data(X_test)
X_train.shape
# Out:
# (1480, 5, 60)

# %%
class CNNDataset(object):
    def __init__(self, X, y):
        self.X = X
        self.y = y
        
    def __getitem__(self, idx):
        data = self.X[idx]
        target = self.y[idx][0]
        return data, target

    def __len__(self):
        return len(self.X)

def prepare_cnn_dataloader(X_train, X_valid, X_test, y_train, y_valid, y_test):
    traindataset = CNNDataset(X_train, y_train)

    trainloader = torch.utils.data.DataLoader(
        traindataset, 
        batch_size=100, 
        shuffle=True, 
        num_workers=4,
    )

    validdataset = CNNDataset(X_valid, y_valid)

    validloader = torch.utils.data.DataLoader(
        validdataset, 
        batch_size=100, 
        shuffle=True, 
        num_workers=4,
    )

    testdataset = CNNDataset(X_test, y_test)

    testloader = torch.utils.data.DataLoader(
        testdataset, 
        batch_size=100, 
        shuffle=True, 
        num_workers=4,
    )

    return trainloader, validloader, testloader

# %%
class CNN(nn.Module):

    def __init__(self):
        super().__init__()
        self.conv1 = nn.Conv1d(5, 32, 3)
        self.relu1 = nn.ReLU()
        self.dp1 = nn.Dropout(0.6)

        self.pool1 = nn.MaxPool1d(2)
        self.flat1 = nn.Flatten()
        self.dp2 = nn.Dropout(0.2)

        self.fc1 = nn.Linear(928, 256)
        self.relu2 = nn.ReLU()
        self.dp3 = nn.Dropout(0.2)

        self.fc2 = nn.Linear(256, 128)
        self.dp4 = nn.Dropout(0.2)

        self.fc3 = nn.Linear(128, 9)

    def forward(self, x):
        x = self.conv1(x)
        x = self.relu1(x)
        x = self.dp1(x)

        x = self.pool1(x)
        x = self.flat1(x)
        x = self.dp2(x)

        x = self.fc1(x)
        x = self.relu2(x)
        x = self.dp3(x)

        x = self.fc2(x)
        x = self.dp4(x)

        x = self.fc3(x)
        
        return x

trainloader, validloader, testloader = prepare_cnn_dataloader(X_train, X_valid, X_test, y_train, y_valid, y_test)
inputs, labels = next(iter(trainloader))
model = CNN()
outputs = model(inputs.float())
labels[:1], outputs[:1]
# Out:
# (tensor([5]),
#  tensor([[ 0.4097, -0.1686, -0.1537, -0.1204,  0.2203, -0.3637, -0.3828, -0.1704,
#           -0.4510]], grad_fn=<SliceBackward>))

# %%
patience = 10
n_epochs = 1000

model = CNN()

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.01, momentum=0.9)
early_stopping = EarlyStopping(patience=patience)
trainloader, validloader, testloader = prepare_cnn_dataloader(X_train, X_valid, X_test, y_train, y_valid, y_test)

trainer = DLTrainer(model, trainloader, validloader, testloader, criterion, optimizer, early_stopping, n_epochs, patience, is_time_series=True)
trainer.train()
# Out:
# [0/1000] train_loss: 2.06755 valid_loss: 1.93913 train_accuracy: 0.15946 valid_accuracy: 0.23529
# [1/1000] train_loss: 1.69035 valid_loss: 1.63631 train_accuracy: 0.36554 valid_accuracy: 0.38945
# [2/1000] train_loss: 1.37123 valid_loss: 1.36818 train_accuracy: 0.47635 valid_accuracy: 0.65314
# [3/1000] train_loss: 1.15672 valid_loss: 1.18099 train_accuracy: 0.61486 valid_accuracy: 0.62880
# [4/1000] train_loss: 0.95699 valid_loss: 0.96221 train_accuracy: 0.67500 valid_accuracy: 0.67951
# [5/1000] train_loss: 0.78383 valid_loss: 0.80441 train_accuracy: 0.72770 valid_accuracy: 0.79310
# [6/1000] train_loss: 0.65229 valid_loss: 0.72526 train_accuracy: 0.78176 valid_accuracy: 0.81136
# [7/1000] train_loss: 0.59581 valid_loss: 0.65065 train_accuracy: 0.81419 valid_accuracy: 0.81744
# [8/1000] train_loss: 0.55954 valid_loss: 0.61878 train_accuracy: 0.81081 valid_accuracy: 0.79513
# [9/1000] train_loss: 0.49325 valid_loss: 0.56526 train_accuracy: 0.83716 valid_accuracy: 0.88438
# [10/1000] train_loss: 0.45833 valid_loss: 0.53332 train_accuracy: 0.85338 valid_accuracy: 0.87424
# [11/1000] train_loss: 0.43820 valid_loss: 0.50980 train_accuracy: 0.86149 valid_accuracy: 0.86207
# [12/1000] train_loss: 0.43122 valid_loss: 0.52233 train_accuracy: 0.86959 valid_accuracy: 0.86410
# EarlyStopping counter: 1 out of 10
# [13/1000] train_loss: 0.40594 valid_loss: 0.44299 train_accuracy: 0.86554 valid_accuracy: 0.88032
# [14/1000] train_loss: 0.32979 valid_loss: 0.41337 train_accuracy: 0.88378 valid_accuracy: 0.89858
# [15/1000] train_loss: 0.30786 valid_loss: 0.37626 train_accuracy: 0.90878 valid_accuracy: 0.90467
# [16/1000] train_loss: 0.27615 valid_loss: 0.39688 train_accuracy: 0.91351 valid_accuracy: 0.89047
# EarlyStopping counter: 1 out of 10
# [17/1000] train_loss: 0.26531 valid_loss: 0.34203 train_accuracy: 0.91216 valid_accuracy: 0.89452
# [18/1000] train_loss: 0.24748 valid_loss: 0.34037 train_accuracy: 0.92095 valid_accuracy: 0.89452
# [19/1000] train_loss: 0.24648 valid_loss: 0.37258 train_accuracy: 0.91892 valid_accuracy: 0.89249
# EarlyStopping counter: 1 out of 10
# [20/1000] train_loss: 0.27219 valid_loss: 0.34845 train_accuracy: 0.91959 valid_accuracy: 0.88844
# EarlyStopping counter: 2 out of 10
# [21/1000] train_loss: 0.21797 valid_loss: 0.29941 train_accuracy: 0.93514 valid_accuracy: 0.92089
# [22/1000] train_loss: 0.20667 valid_loss: 0.30438 train_accuracy: 0.92905 valid_accuracy: 0.90669
# EarlyStopping counter: 1 out of 10
# [23/1000] train_loss: 0.22289 valid_loss: 0.28347 train_accuracy: 0.92770 valid_accuracy: 0.92089
# [24/1000] train_loss: 0.21384 valid_loss: 0.30878 train_accuracy: 0.93378 valid_accuracy: 0.92292
# EarlyStopping counter: 1 out of 10
# [25/1000] train_loss: 0.17794 valid_loss: 0.28623 train_accuracy: 0.94527 valid_accuracy: 0.93306
# EarlyStopping counter: 2 out of 10
# [26/1000] train_loss: 0.18133 valid_loss: 0.27580 train_accuracy: 0.93716 valid_accuracy: 0.92901
# [27/1000] train_loss: 0.16731 valid_loss: 0.26481 train_accuracy: 0.95068 valid_accuracy: 0.92901
# [28/1000] train_loss: 0.17130 valid_loss: 0.25539 train_accuracy: 0.94392 valid_accuracy: 0.93103
# [29/1000] train_loss: 0.15368 valid_loss: 0.25358 train_accuracy: 0.95203 valid_accuracy: 0.93915
# [30/1000] train_loss: 0.14933 valid_loss: 0.25758 train_accuracy: 0.94730 valid_accuracy: 0.92901
# EarlyStopping counter: 1 out of 10
# [31/1000] train_loss: 0.14513 valid_loss: 0.24711 train_accuracy: 0.95068 valid_accuracy: 0.93306
# [32/1000] train_loss: 0.14036 valid_loss: 0.24524 train_accuracy: 0.95338 valid_accuracy: 0.93103
# [33/1000] train_loss: 0.14835 valid_loss: 0.24430 train_accuracy: 0.95203 valid_accuracy: 0.93509
# [34/1000] train_loss: 0.14368 valid_loss: 0.24835 train_accuracy: 0.95473 valid_accuracy: 0.92901
# EarlyStopping counter: 1 out of 10
# [35/1000] train_loss: 0.10323 valid_loss: 0.24161 train_accuracy: 0.96554 valid_accuracy: 0.94118
# [36/1000] train_loss: 0.12520 valid_loss: 0.23025 train_accuracy: 0.95338 valid_accuracy: 0.93509
# [37/1000] train_loss: 0.10620 valid_loss: 0.23863 train_accuracy: 0.96689 valid_accuracy: 0.92698
# EarlyStopping counter: 1 out of 10
# [38/1000] train_loss: 0.11542 valid_loss: 0.23712 train_accuracy: 0.96284 valid_accuracy: 0.94118
# EarlyStopping counter: 2 out of 10
# [39/1000] train_loss: 0.11171 valid_loss: 0.22695 train_accuracy: 0.96486 valid_accuracy: 0.94929
# [40/1000] train_loss: 0.09689 valid_loss: 0.20737 train_accuracy: 0.97500 valid_accuracy: 0.94726
# [41/1000] train_loss: 0.08302 valid_loss: 0.21020 train_accuracy: 0.97297 valid_accuracy: 0.93915
# EarlyStopping counter: 1 out of 10
# [42/1000] train_loss: 0.09848 valid_loss: 0.22367 train_accuracy: 0.96351 valid_accuracy: 0.93306
# EarlyStopping counter: 2 out of 10
# [43/1000] train_loss: 0.10358 valid_loss: 0.21934 train_accuracy: 0.96892 valid_accuracy: 0.94523
# EarlyStopping counter: 3 out of 10
# [44/1000] train_loss: 0.09335 valid_loss: 0.21051 train_accuracy: 0.97230 valid_accuracy: 0.94523
# EarlyStopping counter: 4 out of 10
# [45/1000] train_loss: 0.10128 valid_loss: 0.24777 train_accuracy: 0.96486 valid_accuracy: 0.94523
# EarlyStopping counter: 5 out of 10
# [46/1000] train_loss: 0.07933 valid_loss: 0.22126 train_accuracy: 0.97838 valid_accuracy: 0.94320
# EarlyStopping counter: 6 out of 10
# [47/1000] train_loss: 0.09180 valid_loss: 0.19393 train_accuracy: 0.97500 valid_accuracy: 0.95335
# [48/1000] train_loss: 0.07424 valid_loss: 0.18939 train_accuracy: 0.97770 valid_accuracy: 0.95335
# [49/1000] train_loss: 0.08625 valid_loss: 0.20483 train_accuracy: 0.97635 valid_accuracy: 0.94726
# EarlyStopping counter: 1 out of 10
# [50/1000] train_loss: 0.08069 valid_loss: 0.19328 train_accuracy: 0.97432 valid_accuracy: 0.94929
# EarlyStopping counter: 2 out of 10
# [51/1000] train_loss: 0.08016 valid_loss: 0.19094 train_accuracy: 0.97635 valid_accuracy: 0.94523
# EarlyStopping counter: 3 out of 10
# [52/1000] train_loss: 0.07905 valid_loss: 0.21498 train_accuracy: 0.96959 valid_accuracy: 0.93915
# EarlyStopping counter: 4 out of 10
# [53/1000] train_loss: 0.07802 valid_loss: 0.19976 train_accuracy: 0.97230 valid_accuracy: 0.95132
# EarlyStopping counter: 5 out of 10
# [54/1000] train_loss: 0.07156 valid_loss: 0.20620 train_accuracy: 0.97905 valid_accuracy: 0.94320
# EarlyStopping counter: 6 out of 10
# [55/1000] train_loss: 0.06817 valid_loss: 0.19513 train_accuracy: 0.98041 valid_accuracy: 0.95132
# EarlyStopping counter: 7 out of 10
# [56/1000] train_loss: 0.06758 valid_loss: 0.19638 train_accuracy: 0.97703 valid_accuracy: 0.95335
# EarlyStopping counter: 8 out of 10
# [57/1000] train_loss: 0.05384 valid_loss: 0.18909 train_accuracy: 0.98243 valid_accuracy: 0.94929
# [58/1000] train_loss: 0.05896 valid_loss: 0.19317 train_accuracy: 0.98311 valid_accuracy: 0.94929
# EarlyStopping counter: 1 out of 10
# [59/1000] train_loss: 0.05979 valid_loss: 0.19483 train_accuracy: 0.97973 valid_accuracy: 0.95538
# EarlyStopping counter: 2 out of 10
# [60/1000] train_loss: 0.06251 valid_loss: 0.20695 train_accuracy: 0.98041 valid_accuracy: 0.95335
# EarlyStopping counter: 3 out of 10
# [61/1000] train_loss: 0.07083 valid_loss: 0.18717 train_accuracy: 0.97905 valid_accuracy: 0.95132
# [62/1000] train_loss: 0.06596 valid_loss: 0.19053 train_accuracy: 0.97973 valid_accuracy: 0.95132
# EarlyStopping counter: 1 out of 10
# [63/1000] train_loss: 0.04692 valid_loss: 0.18641 train_accuracy: 0.98514 valid_accuracy: 0.94726
# [64/1000] train_loss: 0.06097 valid_loss: 0.18846 train_accuracy: 0.98514 valid_accuracy: 0.95538
# EarlyStopping counter: 1 out of 10
# [65/1000] train_loss: 0.06918 valid_loss: 0.18875 train_accuracy: 0.97703 valid_accuracy: 0.95132
# EarlyStopping counter: 2 out of 10
# [66/1000] train_loss: 0.06932 valid_loss: 0.21156 train_accuracy: 0.97568 valid_accuracy: 0.94726
# EarlyStopping counter: 3 out of 10
# [67/1000] train_loss: 0.05806 valid_loss: 0.18378 train_accuracy: 0.98176 valid_accuracy: 0.96349
# [68/1000] train_loss: 0.05723 valid_loss: 0.17844 train_accuracy: 0.98649 valid_accuracy: 0.95538
# [69/1000] train_loss: 0.05716 valid_loss: 0.19475 train_accuracy: 0.98108 valid_accuracy: 0.95740
# EarlyStopping counter: 1 out of 10
# [70/1000] train_loss: 0.04399 valid_loss: 0.19681 train_accuracy: 0.98581 valid_accuracy: 0.95335
# EarlyStopping counter: 2 out of 10
# [71/1000] train_loss: 0.03821 valid_loss: 0.19767 train_accuracy: 0.98986 valid_accuracy: 0.95740
# EarlyStopping counter: 3 out of 10
# [72/1000] train_loss: 0.04372 valid_loss: 0.19494 train_accuracy: 0.98784 valid_accuracy: 0.95538
# EarlyStopping counter: 4 out of 10
# [73/1000] train_loss: 0.05968 valid_loss: 0.19330 train_accuracy: 0.98311 valid_accuracy: 0.95335
# EarlyStopping counter: 5 out of 10
# [74/1000] train_loss: 0.03484 valid_loss: 0.19869 train_accuracy: 0.98851 valid_accuracy: 0.94726
# EarlyStopping counter: 6 out of 10
# [75/1000] train_loss: 0.04278 valid_loss: 0.19195 train_accuracy: 0.98649 valid_accuracy: 0.94929
# EarlyStopping counter: 7 out of 10
# [76/1000] train_loss: 0.04133 valid_loss: 0.17365 train_accuracy: 0.98716 valid_accuracy: 0.95538
# [77/1000] train_loss: 0.05411 valid_loss: 0.19017 train_accuracy: 0.98311 valid_accuracy: 0.94929
# EarlyStopping counter: 1 out of 10
# [78/1000] train_loss: 0.05347 valid_loss: 0.20072 train_accuracy: 0.98311 valid_accuracy: 0.95335
# EarlyStopping counter: 2 out of 10
# [79/1000] train_loss: 0.05760 valid_loss: 0.18441 train_accuracy: 0.98176 valid_accuracy: 0.96755
# EarlyStopping counter: 3 out of 10
# [80/1000] train_loss: 0.04080 valid_loss: 0.20297 train_accuracy: 0.98581 valid_accuracy: 0.95335
# EarlyStopping counter: 4 out of 10
# [81/1000] train_loss: 0.03973 valid_loss: 0.18712 train_accuracy: 0.98716 valid_accuracy: 0.95538
# EarlyStopping counter: 5 out of 10
# [82/1000] train_loss: 0.02911 valid_loss: 0.18683 train_accuracy: 0.99324 valid_accuracy: 0.95943
# EarlyStopping counter: 6 out of 10
# [83/1000] train_loss: 0.03982 valid_loss: 0.17747 train_accuracy: 0.98649 valid_accuracy: 0.96957
# EarlyStopping counter: 7 out of 10
# [84/1000] train_loss: 0.04234 valid_loss: 0.20081 train_accuracy: 0.98716 valid_accuracy: 0.95538
# EarlyStopping counter: 8 out of 10
# [85/1000] train_loss: 0.03759 valid_loss: 0.18552 train_accuracy: 0.98986 valid_accuracy: 0.95943
# EarlyStopping counter: 9 out of 10
# [86/1000] train_loss: 0.03249 valid_loss: 0.19459 train_accuracy: 0.99054 valid_accuracy: 0.95740
# EarlyStopping counter: 10 out of 10

# %%
cnn_valid_accuracy, cnn_valid_prediction = trainer.evaluate(validloader)
cnn_test_accuracy, cnn_test_prediction = trainer.evaluate(testloader)
cnn_valid_accuracy, cnn_test_accuracy
# Out:
# (0.9574036511156186, 0.9655870445344129)

# %%
# Compute confusion matrix
cnf_matrix = confusion_matrix(*cnn_test_prediction)
np.set_printoptions(precision=2)

# Plot non-normalized confusion matrix
plot_confusion_matrix(cnf_matrix, classes=activities, title='CNN Testing Confusion Matrix Without Normalization')

# Plot normalized confusion matrix
plot_confusion_matrix(cnf_matrix, classes=activities, normalize=True, title='CNN Testing Normalized Confusion Matrix')
# Out:
# Confusion Matrix Without Normalization
# Normalized Confusion Matrix

# %%
avg_train_losses, avg_valid_losses, train_accuracies, valid_accuracies = trainer.show_evaluation()
plot_avg_loss_per_epoch(avg_train_losses, avg_valid_losses)
plot_accuracy_per_epoch(train_accuracies, valid_accuracies)

# %%
torch.save(model.state_dict(), "cnn_model.pth")

# %%
from joblib import dump

dump(scaler, 'cnn_std_scaler.bin', compress=True)
# Out:
# ['cnn_std_scaler.bin']
