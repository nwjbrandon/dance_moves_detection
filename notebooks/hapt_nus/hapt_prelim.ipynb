# %%
# !gdown --id 1wZbkmhRZxfaAyqNwXRyRJ-ohMORcX0xf
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1wZbkmhRZxfaAyqNwXRyRJ-ohMORcX0xf
# To: /content/daniel_dataset.csv
# 3.34MB [00:00, 29.4MB/s]

# %%
import os
import re
import itertools
import warnings

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from scipy import stats, signal
from sklearn.manifold import TSNE
from sklearn.metrics import accuracy_score, confusion_matrix, f1_score
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn import preprocessing
from sklearn.model_selection import GridSearchCV, train_test_split, cross_val_score
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.model_selection import KFold

import torch
import torchvision
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

warnings.filterwarnings("ignore")
random_state = 42
activities = ["elbow_lock", "hair", "pushback", "rocket", "scarecrow", "shouldershrug", "windows", "zigzag", "logout"]

# %%
def load_dataset(file_name, columns):
    df = pd.read_csv(file_name, header=None)
    df.columns = ["yaw", "pitch", "acc_x", "acc_y", "acc_z", "activityName"]
    df["activity"] = df["activityName"].replace(activities, [0,1,2,3,4,5,6,7,8])
    return df

file_name="prelim_dataset.csv"
columns = ["yaw", "pitch", "acc_x", "acc_y", "acc_z", "activityName"]
df = load_dataset(file_name, columns)
df.sample()
# Out:
#          yaw  pitch   acc_x   acc_y   acc_z activityName  activity
# 46920  15.16  59.58  0.1443  0.0057 -0.1317         hair         1

# %%
test_df = df[:10]
test_df.head()
test_df["activity"].unique()[0]
# Out:
# 1

# %%
def convert_to_timeseries(features, num_time_steps, num_features):
    data = np.reshape(features, newshape=(num_time_steps, num_features))
    return data.T

X = list()
y = list()
df_len = len(df)
for idx in range(0, df_len, 30):
    window_df = df[idx:idx+60]
    labels = window_df["activity"].unique()
    if len(labels) != 1 or len(window_df) < 60:
        continue
    assert len(labels) == 1 and len(window_df) == 60
    features = window_df.drop(columns=["activity", "activityName"]).values
    features = convert_to_timeseries(features, num_time_steps=60, num_features=5)
    X.append(features)
    y.append(labels)

X = np.array(X)
y = np.array(y)

X.shape, y.shape
# Out:
# ((2467, 5, 60), (2467, 1))

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=random_state)
X_valid, X_test, y_valid, y_test = train_test_split(X_test, y_test, test_size=0.5, random_state=random_state)

# %%
def plot_confusion_matrix(cm, classes, normalize=False, title='Confusion Matrix'):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    plt.figure(figsize=(15,8))
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        cmap='Reds'
        print("Normalized Confusion Matrix")
    else:
        cmap='Greens'
        print('Confusion Matrix Without Normalization')

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=90)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.show()

# %%
class EarlyStopping:
    """Early stops the training if validation loss doesn't improve after a given patience."""
    def __init__(self, patience=7, verbose=False, delta=0):
        """
        Args:
            patience (int): How long to wait after last time validation loss improved.
                            上次验证集损失值改善后等待几个epoch
                            Default: 7
            verbose (bool): If True, prints a message for each validation loss improvement.
                            如果是True，为每个验证集损失值改善打印一条信息
                            Default: False
            delta (float): Minimum change in the monitored quantity to qualify as an improvement.
                            监测数量的最小变化，以符合改进的要求
                            Default: 0
        """
        self.patience = patience
        self.verbose = verbose
        self.counter = 0
        self.best_score = None
        self.early_stop = False
        self.val_loss_min = np.Inf
        self.delta = delta

    def __call__(self, val_loss, model):

        score = -val_loss

        if self.best_score is None:
            self.best_score = score
            self.save_checkpoint(val_loss, model)
        elif score < self.best_score + self.delta:
            self.counter += 1
            print(f'EarlyStopping counter: {self.counter} out of {self.patience}')
            if self.counter >= self.patience:
                self.early_stop = True
        else:
            self.best_score = score
            self.save_checkpoint(val_loss, model)
            self.counter = 0

    def save_checkpoint(self, val_loss, model):
        '''
        Saves model when validation loss decrease.
        验证损失减少时保存模型。
        '''
        if self.verbose:
            print(f'Validation loss decreased ({self.val_loss_min:.6f} --> {val_loss:.6f}).  Saving model ...')
        torch.save(model, 'finish_model.pkl')                 # 这里会存储迄今最优的模型
        self.val_loss_min = val_loss

def plot_avg_loss_per_epoch(avg_train_losses, avg_valid_losses):
    # visualize the loss as the network trained
    fig = plt.figure(figsize=(10,8))
    plt.plot(range(1,len(avg_train_losses)+1), avg_train_losses, label='Training Loss')
    plt.plot(range(1,len(avg_valid_losses)+1), avg_valid_losses,label='Validation Loss')

    # find position of lowest validation loss
    minposs = avg_train_losses.index(min(avg_train_losses))+1 
    plt.axvline(minposs, linestyle='--', color='r',label='Early Stopping Checkpoint')

    plt.xlabel('epochs')
    plt.ylabel('loss')
    plt.ylim(0, 2) # consistent scale
    plt.xlim(0, len(avg_train_losses)+1) # consistent scale
    plt.grid(True)
    plt.legend()
    plt.tight_layout()
    plt.show()

def plot_accuracy_per_epoch(train_accuracies, valid_accuracies):
    # visualize the loss as the network trained
    fig = plt.figure(figsize=(10,8))
    plt.plot(range(1,len(train_accuracies)+1), train_accuracies, label='Train Accuracy')
    plt.plot(range(1,len(valid_accuracies)+1), valid_accuracies,label='Valid Accuracy')

    plt.xlabel('epochs')
    plt.ylabel('accuracy')
    plt.ylim(0, 1) # consistent scale
    plt.xlim(0, len(train_accuracies)+1) # consistent scale
    plt.grid(True)
    plt.legend()
    plt.tight_layout()
    plt.show()

# %%
class MLTrainer:
    def __init__(self, model, X_train, X_valid, y_train, y_valid, n_splits=5, random_state=42, shuffle=True):
        self.model = model
        self.X_train = X_train
        self.X_valid = X_valid
        self.y_train = y_train
        self.y_valid = y_valid

        self.n_splits = n_splits
        self.random_state = random_state
        self.shuffle = shuffle
        
        self.clf = None
        self.valid_accuracy = None

    def train(self):
        kf = KFold(n_splits=self.n_splits, random_state=self.random_state, shuffle=self.shuffle)
        X, y = pd.concat([self.X_train, self.X_valid]), pd.concat([self.y_train, self.y_valid])

        accs = []
        for train_index, valid_index in kf.split(X):
            X_train, y_train = X.iloc[train_index], y.iloc[train_index]
            X_valid, y_valid =  X.iloc[valid_index], y.iloc[valid_index]
        
            clf = self.train_split(X_train, y_train)
            accs.append(self.validate_split(clf, X_valid, y_valid))

        self.valid_accuracy = np.mean(accs)

        self.clf = self.model.fit(X, y.values.ravel())

    def train_split(self, X_train, y_train):
        return self.model.fit(X_train, y_train.values.ravel())

    def validate_split(self, clf, X_valid, y_valid):
        pred = clf.predict(X_valid)
        return accuracy_score(pred, y_valid)

    def evaluate(self, X_test, y_test):
        pred = self.clf.predict(X_test)
        return accuracy_score(pred, y_test), (y_test, pred)

    def show_evaluation(self):
        return self.model.__class__.__name__, self.valid_accuracy

# %%
class DLTrainer:
    def __init__(self, model, trainloader, validloader, testloader, criterion, optimizer, early_stopping, n_epochs, patience, is_time_series=False):
        self.model = model
        self.trainloader = trainloader
        self.validloader = validloader
        self.testloader = testloader
        
        self.criterion = criterion
        self.optimizer = optimizer
        self.early_stopping = early_stopping
        self.n_epochs = n_epochs
        self.patience = patience
        self.is_time_series = is_time_series

        self.avg_train_losses = []
        self.avg_valid_losses = [] 
        self.train_accuracies = []
        self.valid_accuracies = []

    def train(self):
        self.model.cuda()
        for epoch in range(self.n_epochs):  # loop over the dataset multiple times
            train_correct, train_total, train_loss = self.train_epoch()
            valid_correct, valid_total, valid_loss = self.validate_epoch()

            # calculate average loss over an epoch
            train_accuracy = train_correct / train_total
            valid_accuracy = valid_correct / valid_total

            self.avg_train_losses.append(train_loss)
            self.avg_valid_losses.append(valid_loss)
            self.train_accuracies.append(train_accuracy)
            self.valid_accuracies.append(valid_accuracy)

            log_message = f'[{str(epoch)}/{str(self.n_epochs)}] train_loss: {train_loss:.5f} valid_loss: {valid_loss:.5f} train_accuracy: {train_accuracy:.5f} valid_accuracy: {valid_accuracy:.5f}'
            print(log_message)

            self.early_stopping(valid_loss, self.model)
            
            if self.early_stopping.early_stop:
                break

    def train_epoch(self):
        correct = 0
        total = 0
        losses = []

        self.model.train()
        for data in self.trainloader:
            inputs, labels = data

            # if self.is_time_series:
            #     inputs = inputs.permute(0, 2, 1)

            inputs = inputs.to("cuda")
            labels = labels.to("cuda")

            self.optimizer.zero_grad()

            outputs = self.model(inputs.float())

            loss = self.criterion(outputs, labels)
            loss.backward()
            self.optimizer.step()

            losses.append(loss.item())

            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

        return correct, total, np.mean(losses)

    def validate_epoch(self):
        correct = 0
        total = 0
        losses = []

        self.model.eval()
        for data in validloader:
            inputs, labels = data

            # if self.is_time_series:
            #     inputs = inputs.permute(0, 2, 1)

            inputs = inputs.to("cuda")
            labels = labels.to("cuda")

            outputs = self.model(inputs.float())
            loss = self.criterion(outputs, labels)
            losses.append(loss.item())

            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

        return correct, total, np.mean(losses)

    def evaluate(self, dataloader):
        correct = 0
        total = 0
        actual = []
        expected = []

        with torch.no_grad():
            for data in dataloader:
                inputs, labels = data

                # if self.is_time_series:
                #     inputs = inputs.permute(0, 2, 1)

                inputs = inputs.to("cuda")
                labels = labels.to("cuda")
                outputs = self.model(inputs.float())
                _, predicted = torch.max(outputs.data, 1)
                total += labels.size(0)
                correct += (predicted == labels).sum().item()
                expected += labels.cpu()
                actual += predicted.cpu()

        return correct/total, (expected, actual)

    def show_evaluation(self):
        return self.avg_train_losses, self.avg_valid_losses, self.train_accuracies, self.valid_accuracies

# %%
scaler = preprocessing.StandardScaler()
# https://stackoverflow.com/questions/53870113/using-standardscaler-on-3d-data
def scale_data(data, is_train=False):
    num_instances, num_time_steps, num_features = data.shape
    data = np.reshape(data, newshape=(-1, num_features))
    if is_train:
        data = scaler.fit_transform(data)
    else:
        data = scaler.transform(data)
    data = np.reshape(data, newshape=(num_instances, num_time_steps, num_features))
    return data

X_train = scale_data(X_train, is_train=True)
X_valid = scale_data(X_valid)
X_test = scale_data(X_test)
X_train.shape
# Out:
# (1480, 5, 60)

# %%
class CNNDataset(object):
    def __init__(self, X, y):
        self.X = X
        self.y = y
        
    def __getitem__(self, idx):
        data = self.X[idx]
        target = self.y[idx][0]
        return data, target

    def __len__(self):
        return len(self.X)

def prepare_cnn_dataloader(X_train, X_valid, X_test, y_train, y_valid, y_test):
    traindataset = CNNDataset(X_train, y_train)

    trainloader = torch.utils.data.DataLoader(
        traindataset, 
        batch_size=100, 
        shuffle=True, 
        num_workers=4,
    )

    validdataset = CNNDataset(X_valid, y_valid)

    validloader = torch.utils.data.DataLoader(
        validdataset, 
        batch_size=100, 
        shuffle=True, 
        num_workers=4,
    )

    testdataset = CNNDataset(X_test, y_test)

    testloader = torch.utils.data.DataLoader(
        testdataset, 
        batch_size=100, 
        shuffle=True, 
        num_workers=4,
    )

    return trainloader, validloader, testloader

# %%
class CNN(nn.Module):

    def __init__(self):
        super().__init__()
        self.conv1 = nn.Conv1d(5, 32, 3)
        self.relu1 = nn.ReLU()
        self.dp1 = nn.Dropout(0.6)

        self.pool1 = nn.MaxPool1d(2)
        self.flat1 = nn.Flatten()
        self.dp2 = nn.Dropout(0.2)

        self.fc1 = nn.Linear(928, 256)
        self.relu2 = nn.ReLU()
        self.dp3 = nn.Dropout(0.2)

        self.fc2 = nn.Linear(256, 128)
        self.dp4 = nn.Dropout(0.2)

        self.fc3 = nn.Linear(128, 9)

    def forward(self, x):
        x = self.conv1(x)
        x = self.relu1(x)
        x = self.dp1(x)

        x = self.pool1(x)
        x = self.flat1(x)
        x = self.dp2(x)

        x = self.fc1(x)
        x = self.relu2(x)
        x = self.dp3(x)

        x = self.fc2(x)
        x = self.dp4(x)

        x = self.fc3(x)
        
        return x

trainloader, validloader, testloader = prepare_cnn_dataloader(X_train, X_valid, X_test, y_train, y_valid, y_test)
inputs, labels = next(iter(trainloader))
model = CNN()
outputs = model(inputs.float())
labels[:1], outputs[:1]
# Out:
# (tensor([0]),
#  tensor([[ 0.0059,  0.0610,  0.0687, -0.0514,  0.0157, -0.0423,  0.0153,  0.0081,
#            0.1342]], grad_fn=<SliceBackward>))

# %%
patience = 10
n_epochs = 1000

model = CNN()

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.01, momentum=0.9)
early_stopping = EarlyStopping(patience=patience)
trainloader, validloader, testloader = prepare_cnn_dataloader(X_train, X_valid, X_test, y_train, y_valid, y_test)

trainer = DLTrainer(model, trainloader, validloader, testloader, criterion, optimizer, early_stopping, n_epochs, patience, is_time_series=True)
trainer.train()
# Out:
# [0/1000] train_loss: 2.12048 valid_loss: 2.03598 train_accuracy: 0.18716 valid_accuracy: 0.32252
# [1/1000] train_loss: 1.76180 valid_loss: 1.65155 train_accuracy: 0.32365 valid_accuracy: 0.39757
# [2/1000] train_loss: 1.37785 valid_loss: 1.33584 train_accuracy: 0.48311 valid_accuracy: 0.57809
# [3/1000] train_loss: 1.15452 valid_loss: 1.14175 train_accuracy: 0.59459 valid_accuracy: 0.64503
# EarlyStopping counter: 5 out of 10
# [75/1000] train_loss: 0.06135 valid_loss: 0.22233 train_accuracy: 0.98378 valid_accuracy: 0.93712
# EarlyStopping counter: 6 out of 10
# [76/1000] train_loss: 0.06772 valid_loss: 0.17288 train_accuracy: 0.97905 valid_accuracy: 0.95538
# [77/1000] train_loss: 0.04564 valid_loss: 0.17877 train_accuracy: 0.98378 valid_accuracy: 0.95335
# EarlyStopping counter: 1 out of 10
# [78/1000] train_loss: 0.04603 valid_loss: 0.18618 train_accuracy: 0.98851 valid_accuracy: 0.95132
# EarlyStopping counter: 2 out of 10
# [79/1000] train_loss: 0.04115 valid_loss: 0.19221 train_accuracy: 0.98378 valid_accuracy: 0.95335
# EarlyStopping counter: 3 out of 10
# [80/1000] train_loss: 0.05543 valid_loss: 0.19072 train_accuracy: 0.98446 valid_accuracy: 0.95538
# EarlyStopping counter: 4 out of 10
# [81/1000] train_loss: 0.05291 valid_loss: 0.17454 train_accuracy: 0.98243 valid_accuracy: 0.94929
# EarlyStopping counter: 5 out of 10
# [82/1000] train_loss: 0.04170 valid_loss: 0.18995 train_accuracy: 0.98919 valid_accuracy: 0.95335
# EarlyStopping counter: 6 out of 10
# [83/1000] train_loss: 0.04183 valid_loss: 0.19490 train_accuracy: 0.98581 valid_accuracy: 0.94929
# EarlyStopping counter: 7 out of 10
# [84/1000] train_loss: 0.03277 valid_loss: 0.19626 train_accuracy: 0.99122 valid_accuracy: 0.94929
# EarlyStopping counter: 8 out of 10
# [85/1000] train_loss: 0.03888 valid_loss: 0.18974 train_accuracy: 0.99054 valid_accuracy: 0.94726
# EarlyStopping counter: 9 out of 10
# [86/1000] train_loss: 0.04173 valid_loss: 0.18825 train_accuracy: 0.98784 valid_accuracy: 0.95132
# EarlyStopping counter: 10 out of 10

# %%
cnn_valid_accuracy, cnn_valid_prediction = trainer.evaluate(validloader)
cnn_test_accuracy, cnn_test_prediction = trainer.evaluate(testloader)
cnn_valid_accuracy, cnn_test_accuracy
# Out:
# (0.9513184584178499, 0.9595141700404858)

# %%
# Compute confusion matrix
cnf_matrix = confusion_matrix(*cnn_test_prediction)
np.set_printoptions(precision=2)

# Plot non-normalized confusion matrix
plot_confusion_matrix(cnf_matrix, classes=activities, title='CNN Testing Confusion Matrix Without Normalization')

# Plot normalized confusion matrix
plot_confusion_matrix(cnf_matrix, classes=activities, normalize=True, title='CNN Testing Normalized Confusion Matrix')
# Out:
# Confusion Matrix Without Normalization
# Normalized Confusion Matrix

# %%
avg_train_losses, avg_valid_losses, train_accuracies, valid_accuracies = trainer.show_evaluation()
plot_avg_loss_per_epoch(avg_train_losses, avg_valid_losses)
plot_accuracy_per_epoch(train_accuracies, valid_accuracies)

# %%
def compute_mean(data):
    return np.mean(data)

def compute_variance(data):
    return np.var(data)

def compute_median_absolute_deviation(data):
    return stats.median_absolute_deviation(data)

def compute_root_mean_square(data):
    def compose(*fs):
        def wrapped(x):
            for f in fs[::-1]:
                x = f(x)
            return x
        return wrapped
    rms = compose(np.sqrt, np.mean, np.square)
    return rms(data)

def compute_interquartile_range(data):
    return stats.iqr(data)

def compute_percentile_75(data):
    return np.percentile(data, 75)

def compute_kurtosis(data):
    return stats.kurtosis(data)

def compute_min_max(data):
    return np.max(data) - np.min(data)

def compute_signal_magnitude_area(data):
    return np.sum(data) / len(data)

def compute_zero_crossing_rate(data):
    return ((data[:-1] * data[1:]) < 0).sum()

def compute_spectral_centroid(data):
    spectrum = np.abs(np.fft.rfft(data))
    normalized_spectrum = spectrum / np.sum(spectrum)  # like a probability mass function
    normalized_frequencies = np.linspace(0, 1, len(spectrum))
    spectral_centroid = np.sum(normalized_frequencies * normalized_spectrum)
    return spectral_centroid

def compute_spectral_entropy(data):
    freqs, power_density = signal.welch(data)
    return stats.entropy(power_density)

def compute_spectral_energy(data):
    freqs, power_density = signal.welch(data)
    return np.sum(np.square(power_density))

def compute_principle_frequency(data):
    freqs, power_density = signal.welch(data)
    return freqs[np.argmax(np.square(power_density))]

# %%
feature_names = []
for i in ["yaw", "pitch", "acc_x", "acc_y", "acc_z"]:
        for j in ["_mean", "_var", "_mad", "_rms", "_iqr", "_per75", "_kurtosis", "_min_max", "_sma", "_zcr", "_sc", "_entropy", "_energy", "_pfreq"]:
            feature_names.append(i+j)

n_features = len(feature_names)

def rename_raw_data_headers(X, columns):
    X = pd.DataFrame(X)
    X.columns = columns
    return X

def extract_raw_data_features_per_row(f_n):
    f1_mean = compute_mean(f_n)
    f1_var = compute_variance(f_n)
    f1_mad = compute_median_absolute_deviation(f_n)
    f1_rms = compute_root_mean_square(f_n)
    f1_iqr = compute_interquartile_range(f_n)
    f1_per75 = compute_percentile_75(f_n)
    f1_kurtosis = compute_kurtosis(f_n)
    f1_min_max = compute_min_max(f_n)
    f1_sma = compute_signal_magnitude_area(f_n)
    f1_zcr = compute_zero_crossing_rate(f_n)
    f1_sc = compute_spectral_centroid(f_n)
    f1_entropy = compute_spectral_entropy(f_n)
    f1_energy = compute_spectral_energy(f_n)
    f1_pfreq = compute_principle_frequency(f_n)
    return f1_mean, f1_var, f1_mad, f1_rms, f1_iqr, f1_per75, f1_kurtosis, f1_min_max, f1_sma, f1_zcr, f1_sc, f1_entropy, f1_energy, f1_pfreq

def extract_raw_data_features(X):
    new_features = np.ones((X.shape[0], n_features))
    rows = X.shape[0]
    cols = X.shape[1]

    for row in range(rows):
        features = []
        for col in range(cols):
            f_n = X[row][col]
            feature = extract_raw_data_features_per_row(f_n)
            features.extend(feature)
        new_features[row] = np.array(features)
        
    scaler = preprocessing.StandardScaler()
    new_features = scaler.fit_transform(new_features)

    df = rename_raw_data_headers(new_features, feature_names)
    return df


def prepare_raw_data_dataframe(X, y, random_state=42):
    X = extract_raw_data_features(X)
    y = pd.DataFrame({"activity": y[:,0]})

    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=random_state)
    X_valid, X_test, y_valid, y_test = train_test_split(X_test, y_test, test_size=0.5, random_state=random_state)

    return X_train, X_valid, X_test, X, y_train, y_valid, y_test, y

X_train, X_valid, X_test, X_explore, y_train, y_valid, y_test, y_explore = prepare_raw_data_dataframe(X, y)

# %%
X_explore["activityName"] = y_explore["activity"].replace([0,1,2,3,4,5,6,7,8], activities)
X_explore.sample()
# Out:
#      yaw_mean   yaw_var   yaw_mad  ...  acc_z_energy  acc_z_pfreq  activityName
# 910  0.494588 -0.465479 -0.038787  ...      0.086394    -0.518782       windows
#
# [1 rows x 71 columns]

# %%
exploratory_features = ["acc_z_mad", "yaw_entropy", "yaw_entropy"]

def plot_histogram_activity_distribution(df, feature):
    sns.set_palette("Set1", desat=0.80)
    facetgrid = sns.FacetGrid(df, hue='activityName', size=6,aspect=2)
    facetgrid.map(sns.distplot, feature, hist=False).add_legend()
    plt.show()

for feature in exploratory_features:
    plot_histogram_activity_distribution(X_explore, feature)

# %%
exploratory_features = ["acc_z_mad", "yaw_entropy", "yaw_entropy"]

def plot_boxplot_activity_distribution(data, y):
    sns.boxplot(x='activityName', y=y, data=data)
    plt.axhline(y=0.08, xmin=0.1, xmax=0.9,c='m',dashes=(5,3))
    plt.title(feature, fontsize=15)
    plt.xticks(rotation = 40)
    plt.show()

for feature in exploratory_features:
    plot_boxplot_activity_distribution(X_explore, feature)

# %%
perplexities = [2,5,10,20,50]

def plot_tsne(X_data, y_data, perplexity, n_iter=1000, img_name_prefix='t-sne'):
    # perform t-sne
    X_reduced = TSNE(verbose=2, perplexity=perplexity).fit_transform(X_data)
    
    # prepare the data for seaborn         
    df = pd.DataFrame({'x':X_reduced[:,0], 'y':X_reduced[:,1] ,'label':y_data})
    
    # draw the plot in appropriate place in the grid
    sns.lmplot(data=df, x='x', y='y', hue='label', fit_reg=False, size=8,\
                palette="Set1")
    plt.title("perplexity : {} and max_iter : {}".format(perplexity, n_iter))
    img_name = img_name_prefix + '_perp_{}_iter_{}.png'.format(perplexity, n_iter)
    plt.show()

for perplexity in perplexities:
    X_pre_tsne = X_explore.drop(columns=['activityName'], axis=1)
    y_pre_tsne = X_explore['activityName']
    plot_tsne(X_data=X_pre_tsne, y_data=y_pre_tsne, perplexity=perplexity)
# Out:
# [t-SNE] Computing 7 nearest neighbors...
# [t-SNE] Indexed 2467 samples in 0.013s...
# [t-SNE] Computed neighbors for 2467 samples in 0.517s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 2467
# [t-SNE] Computed conditional probabilities for sample 2000 / 2467
# [t-SNE] Computed conditional probabilities for sample 2467 / 2467
# [t-SNE] Mean sigma: 0.645491
# [t-SNE] Computed conditional probabilities in 0.017s
# [t-SNE] Iteration 50: error = 106.8215866, gradient norm = 0.2000805 (50 iterations in 1.090s)
# [t-SNE] Iteration 100: error = 90.3986969, gradient norm = 0.1646685 (50 iterations in 0.507s)
# [t-SNE] Iteration 150: error = 84.8206787, gradient norm = 0.1404045 (50 iterations in 0.386s)
# [t-SNE] Iteration 200: error = 81.7445450, gradient norm = 0.1135056 (50 iterations in 0.377s)
# [t-SNE] Iteration 250: error = 79.6416931, gradient norm = 0.1119415 (50 iterations in 0.378s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 79.641693
# [t-SNE] Iteration 300: error = 2.4687829, gradient norm = 0.0025200 (50 iterations in 0.424s)
# [t-SNE] Iteration 350: error = 1.9181950, gradient norm = 0.0014635 (50 iterations in 0.455s)
# [t-SNE] Iteration 400: error = 1.6588441, gradient norm = 0.0010245 (50 iterations in 0.442s)
# [t-SNE] Iteration 450: error = 1.5009005, gradient norm = 0.0008193 (50 iterations in 0.480s)
# [t-SNE] Iteration 500: error = 1.3908648, gradient norm = 0.0006442 (50 iterations in 0.444s)
# [t-SNE] Iteration 550: error = 1.3085423, gradient norm = 0.0005612 (50 iterations in 0.441s)
# [t-SNE] Iteration 600: error = 1.2430751, gradient norm = 0.0004875 (50 iterations in 0.513s)
# [t-SNE] Iteration 650: error = 1.1905732, gradient norm = 0.0004450 (50 iterations in 0.482s)
# [t-SNE] Iteration 700: error = 1.1469779, gradient norm = 0.0003772 (50 iterations in 0.464s)
# [t-SNE] Iteration 750: error = 1.1100481, gradient norm = 0.0003457 (50 iterations in 0.476s)
# [t-SNE] Iteration 800: error = 1.0777843, gradient norm = 0.0003083 (50 iterations in 0.456s)
# [t-SNE] Iteration 850: error = 1.0499220, gradient norm = 0.0002904 (50 iterations in 0.448s)
# [t-SNE] Iteration 900: error = 1.0256590, gradient norm = 0.0002756 (50 iterations in 0.463s)
# [t-SNE] Iteration 950: error = 1.0039573, gradient norm = 0.0002482 (50 iterations in 0.443s)
# [t-SNE] Iteration 1000: error = 0.9844646, gradient norm = 0.0002426 (50 iterations in 0.451s)
# [t-SNE] KL divergence after 1000 iterations: 0.984465
# [t-SNE] Computing 16 nearest neighbors...
# [t-SNE] Indexed 2467 samples in 0.019s...
# [t-SNE] Computed neighbors for 2467 samples in 0.737s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 2467
# [t-SNE] Computed conditional probabilities for sample 2000 / 2467
# [t-SNE] Computed conditional probabilities for sample 2467 / 2467
# [t-SNE] Mean sigma: 1.093768
# [t-SNE] Computed conditional probabilities in 0.024s
# [t-SNE] Iteration 50: error = 95.3457031, gradient norm = 0.1512785 (50 iterations in 1.130s)
# [t-SNE] Iteration 100: error = 79.0668640, gradient norm = 0.0940808 (50 iterations in 0.504s)
# [t-SNE] Iteration 150: error = 74.1499023, gradient norm = 0.0750155 (50 iterations in 0.415s)
# [t-SNE] Iteration 200: error = 71.6898651, gradient norm = 0.0773405 (50 iterations in 0.400s)
# [t-SNE] Iteration 250: error = 70.1010818, gradient norm = 0.0601616 (50 iterations in 0.417s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 70.101082
# [t-SNE] Iteration 300: error = 1.9106978, gradient norm = 0.0020482 (50 iterations in 0.435s)
# [t-SNE] Iteration 350: error = 1.4631424, gradient norm = 0.0009170 (50 iterations in 0.470s)
# [t-SNE] Iteration 400: error = 1.2750583, gradient norm = 0.0006208 (50 iterations in 0.455s)
# [t-SNE] Iteration 450: error = 1.1662700, gradient norm = 0.0004825 (50 iterations in 0.455s)
# [t-SNE] Iteration 500: error = 1.0939515, gradient norm = 0.0003878 (50 iterations in 0.484s)
# [t-SNE] Iteration 550: error = 1.0412391, gradient norm = 0.0003200 (50 iterations in 0.447s)
# [t-SNE] Iteration 600: error = 1.0013978, gradient norm = 0.0002712 (50 iterations in 0.464s)
# [t-SNE] Iteration 650: error = 0.9694674, gradient norm = 0.0002447 (50 iterations in 0.447s)
# [t-SNE] Iteration 700: error = 0.9435425, gradient norm = 0.0002166 (50 iterations in 0.476s)
# [t-SNE] Iteration 750: error = 0.9219673, gradient norm = 0.0002004 (50 iterations in 0.443s)
# [t-SNE] Iteration 800: error = 0.9036950, gradient norm = 0.0001861 (50 iterations in 0.450s)
# [t-SNE] Iteration 850: error = 0.8880165, gradient norm = 0.0001752 (50 iterations in 0.452s)
# [t-SNE] Iteration 900: error = 0.8742659, gradient norm = 0.0001687 (50 iterations in 0.446s)
# [t-SNE] Iteration 950: error = 0.8630346, gradient norm = 0.0001634 (50 iterations in 0.435s)
# [t-SNE] Iteration 1000: error = 0.8533209, gradient norm = 0.0001486 (50 iterations in 0.442s)
# [t-SNE] KL divergence after 1000 iterations: 0.853321
# [t-SNE] Computing 31 nearest neighbors...
# [t-SNE] Indexed 2467 samples in 0.018s...
# [t-SNE] Computed neighbors for 2467 samples in 0.757s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 2467
# [t-SNE] Computed conditional probabilities for sample 2000 / 2467
# [t-SNE] Computed conditional probabilities for sample 2467 / 2467
# [t-SNE] Mean sigma: 1.382155
# [t-SNE] Computed conditional probabilities in 0.037s
# [t-SNE] Iteration 50: error = 86.5387497, gradient norm = 0.1466954 (50 iterations in 0.995s)
# [t-SNE] Iteration 100: error = 70.9127655, gradient norm = 0.0645714 (50 iterations in 0.470s)
# [t-SNE] Iteration 150: error = 66.5858917, gradient norm = 0.0519055 (50 iterations in 0.434s)
# [t-SNE] Iteration 200: error = 64.3891068, gradient norm = 0.0413860 (50 iterations in 0.405s)
# [t-SNE] Iteration 250: error = 63.0379562, gradient norm = 0.0352323 (50 iterations in 0.434s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 63.037956
# [t-SNE] Iteration 300: error = 1.5014462, gradient norm = 0.0013123 (50 iterations in 0.460s)
# [t-SNE] Iteration 350: error = 1.1227264, gradient norm = 0.0006288 (50 iterations in 0.463s)
# [t-SNE] Iteration 400: error = 0.9802289, gradient norm = 0.0004234 (50 iterations in 0.463s)
# [t-SNE] Iteration 450: error = 0.9032611, gradient norm = 0.0003203 (50 iterations in 0.454s)
# [t-SNE] Iteration 500: error = 0.8541887, gradient norm = 0.0002578 (50 iterations in 0.467s)
# [t-SNE] Iteration 550: error = 0.8198421, gradient norm = 0.0002142 (50 iterations in 0.454s)
# [t-SNE] Iteration 600: error = 0.7942436, gradient norm = 0.0001939 (50 iterations in 0.463s)
# [t-SNE] Iteration 650: error = 0.7749071, gradient norm = 0.0001744 (50 iterations in 0.475s)
# [t-SNE] Iteration 700: error = 0.7591119, gradient norm = 0.0001608 (50 iterations in 0.460s)
# [t-SNE] Iteration 750: error = 0.7469442, gradient norm = 0.0001589 (50 iterations in 0.454s)
# [t-SNE] Iteration 800: error = 0.7371185, gradient norm = 0.0001419 (50 iterations in 0.468s)
# [t-SNE] Iteration 850: error = 0.7287925, gradient norm = 0.0001299 (50 iterations in 0.456s)
# [t-SNE] Iteration 900: error = 0.7210170, gradient norm = 0.0001303 (50 iterations in 0.464s)
# [t-SNE] Iteration 950: error = 0.7139046, gradient norm = 0.0001198 (50 iterations in 0.458s)
# [t-SNE] Iteration 1000: error = 0.7080325, gradient norm = 0.0001226 (50 iterations in 0.448s)
# [t-SNE] KL divergence after 1000 iterations: 0.708032
# [t-SNE] Computing 61 nearest neighbors...
# [t-SNE] Indexed 2467 samples in 0.023s...
# [t-SNE] Computed neighbors for 2467 samples in 0.863s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 2467
# [t-SNE] Computed conditional probabilities for sample 2000 / 2467
# [t-SNE] Computed conditional probabilities for sample 2467 / 2467
# [t-SNE] Mean sigma: 1.714395
# [t-SNE] Computed conditional probabilities in 0.073s
# [t-SNE] Iteration 50: error = 75.3907928, gradient norm = 0.1159373 (50 iterations in 1.088s)
# [t-SNE] Iteration 100: error = 62.6893845, gradient norm = 0.0452950 (50 iterations in 0.529s)
# [t-SNE] Iteration 150: error = 59.3860626, gradient norm = 0.0376033 (50 iterations in 0.494s)
# [t-SNE] Iteration 200: error = 57.7156677, gradient norm = 0.0332468 (50 iterations in 0.496s)
# [t-SNE] Iteration 250: error = 56.6951981, gradient norm = 0.0207682 (50 iterations in 0.504s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 56.695198
# [t-SNE] Iteration 300: error = 1.1172853, gradient norm = 0.0011084 (50 iterations in 0.507s)
# [t-SNE] Iteration 350: error = 0.8121376, gradient norm = 0.0004681 (50 iterations in 0.552s)
# [t-SNE] Iteration 400: error = 0.7051075, gradient norm = 0.0002984 (50 iterations in 0.528s)
# [t-SNE] Iteration 450: error = 0.6536570, gradient norm = 0.0002330 (50 iterations in 0.535s)
# [t-SNE] Iteration 500: error = 0.6245003, gradient norm = 0.0001856 (50 iterations in 0.540s)
# [t-SNE] Iteration 550: error = 0.6062343, gradient norm = 0.0001739 (50 iterations in 0.529s)
# [t-SNE] Iteration 600: error = 0.5946290, gradient norm = 0.0001554 (50 iterations in 0.524s)
# [t-SNE] Iteration 650: error = 0.5852005, gradient norm = 0.0001482 (50 iterations in 0.525s)
# [t-SNE] Iteration 700: error = 0.5773641, gradient norm = 0.0001360 (50 iterations in 0.508s)
# [t-SNE] Iteration 750: error = 0.5705417, gradient norm = 0.0001278 (50 iterations in 0.518s)
# [t-SNE] Iteration 800: error = 0.5650644, gradient norm = 0.0001228 (50 iterations in 0.520s)
# [t-SNE] Iteration 850: error = 0.5601726, gradient norm = 0.0001211 (50 iterations in 0.521s)
# [t-SNE] Iteration 900: error = 0.5560801, gradient norm = 0.0001228 (50 iterations in 0.513s)
# [t-SNE] Iteration 950: error = 0.5529391, gradient norm = 0.0001052 (50 iterations in 0.534s)
# [t-SNE] Iteration 1000: error = 0.5495828, gradient norm = 0.0001146 (50 iterations in 0.531s)
# [t-SNE] KL divergence after 1000 iterations: 0.549583
# [t-SNE] Computing 151 nearest neighbors...
# [t-SNE] Indexed 2467 samples in 0.020s...
# [t-SNE] Computed neighbors for 2467 samples in 0.974s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 2467
# [t-SNE] Computed conditional probabilities for sample 2000 / 2467
# [t-SNE] Computed conditional probabilities for sample 2467 / 2467
# [t-SNE] Mean sigma: 2.342614
# [t-SNE] Computed conditional probabilities in 0.181s
# [t-SNE] Iteration 50: error = 65.6589966, gradient norm = 0.0897809 (50 iterations in 1.087s)
# [t-SNE] Iteration 100: error = 54.8531914, gradient norm = 0.0316775 (50 iterations in 0.706s)
# [t-SNE] Iteration 150: error = 52.6999893, gradient norm = 0.0163723 (50 iterations in 0.666s)
# [t-SNE] Iteration 200: error = 51.7446289, gradient norm = 0.0150953 (50 iterations in 0.646s)
# [t-SNE] Iteration 250: error = 51.1945724, gradient norm = 0.0110489 (50 iterations in 0.691s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 51.194572
# [t-SNE] Iteration 300: error = 0.6867496, gradient norm = 0.0009494 (50 iterations in 0.659s)
# [t-SNE] Iteration 350: error = 0.4917990, gradient norm = 0.0003272 (50 iterations in 0.654s)
# [t-SNE] Iteration 400: error = 0.4288137, gradient norm = 0.0001986 (50 iterations in 0.661s)
# [t-SNE] Iteration 450: error = 0.4027470, gradient norm = 0.0001589 (50 iterations in 0.656s)
# [t-SNE] Iteration 500: error = 0.3909733, gradient norm = 0.0001365 (50 iterations in 0.665s)
# [t-SNE] Iteration 550: error = 0.3836511, gradient norm = 0.0001241 (50 iterations in 0.658s)
# [t-SNE] Iteration 600: error = 0.3786368, gradient norm = 0.0001302 (50 iterations in 0.638s)
# [t-SNE] Iteration 650: error = 0.3754290, gradient norm = 0.0001081 (50 iterations in 0.651s)
# [t-SNE] Iteration 700: error = 0.3726683, gradient norm = 0.0001030 (50 iterations in 0.654s)
# [t-SNE] Iteration 750: error = 0.3702791, gradient norm = 0.0000951 (50 iterations in 0.644s)
# [t-SNE] Iteration 800: error = 0.3681080, gradient norm = 0.0001014 (50 iterations in 0.649s)
# [t-SNE] Iteration 850: error = 0.3664119, gradient norm = 0.0000966 (50 iterations in 0.649s)
# [t-SNE] Iteration 900: error = 0.3649103, gradient norm = 0.0000871 (50 iterations in 0.672s)
# [t-SNE] Iteration 950: error = 0.3634253, gradient norm = 0.0000864 (50 iterations in 0.649s)
# [t-SNE] Iteration 1000: error = 0.3621192, gradient norm = 0.0000815 (50 iterations in 0.653s)
# [t-SNE] KL divergence after 1000 iterations: 0.362119

# %%
trainer = MLTrainer(SVC(kernel='rbf', C=1000, gamma = 0.001, class_weight='balanced', probability=True), X_train, X_valid, y_train, y_valid)

trainer.train()
svc_model_name, svc_valid_accuracy = trainer.show_evaluation()
svc_test_accuracy, svc_test_prediction = trainer.evaluate(X_test, y_test)

print(svc_valid_accuracy, svc_test_accuracy)
# Out:
# 0.998984771573604 1.0

# %%
cnf_matrix = confusion_matrix(*svc_test_prediction)
np.set_printoptions(precision=2)

# Plot non-normalized confusion matrix
plt.figure(figsize=(15,8))
plot_confusion_matrix(cnf_matrix, classes=activities, title='SVC Testing Confusion Matrix Without Normalization')

# Plot normalized confusion matrix
plt.figure(figsize=(15,8))
plot_confusion_matrix(cnf_matrix, classes=activities, normalize=True, title='SVC Testing Normalized Confusion Matrix')

plt.show()
# Out:
# Confusion Matrix Without Normalization
# Normalized Confusion Matrix

# %%
class DNNDataset(object):
    def __init__(self, X, y):
        self.X = X
        self.y = y
        
    def __getitem__(self, idx):
        data = self.X.iloc[idx].values
        target = self.y.iloc[idx].values[0] 
        return data, target

    def __len__(self):
        return len(self.X)

def prepare_dnn_dataloader(X_train, X_valid, X_test, y_train, y_valid, y_test):
    traindataset = DNNDataset(X_train, y_train)

    trainloader = torch.utils.data.DataLoader(
        traindataset, 
        batch_size=100, 
        shuffle=True, 
        num_workers=4,
    )

    validdataset = DNNDataset(X_valid, y_valid)

    validloader = torch.utils.data.DataLoader(
        validdataset, 
        batch_size=100, 
        shuffle=True, 
        num_workers=4,
    )

    testdataset = DNNDataset(X_test, y_test)

    testloader = torch.utils.data.DataLoader(
        testdataset, 
        batch_size=100, 
        shuffle=True, 
        num_workers=4,
    )

    return trainloader, validloader, testloader

# %%
class DNN(nn.Module):

    def __init__(self):
        super().__init__()
        self.fc1 = nn.Linear(70, 70)
        self.dp1 = nn.Dropout(0.1)

        self.fc2 = nn.Linear(70, 50)
        self.dp2 = nn.Dropout(0.1)

        self.fc3 = nn.Linear(50, 20)
        self.dp3 = nn.Dropout(0.1)
        
        self.fc4 = nn.Linear(20,9)

    def forward(self, x):
        x = self.fc1(x)
        x = self.dp1(x)

        x = self.fc2(x)
        x = self.dp2(x)

        x = self.fc3(x)
        x = self.dp3(x)

        x = self.fc4(x)
        return x

trainloader, validloader, testloader = prepare_dnn_dataloader(X_train, X_valid, X_test, y_train, y_valid, y_test)
inputs, labels = next(iter(trainloader))
model = DNN()
outputs = model(inputs.float())
labels[:1], outputs[:1]
# Out:
# (tensor([3]),
#  tensor([[-0.0218,  0.2601,  0.0980, -0.1398,  0.1411,  0.0520,  0.1417,  0.0085,
#            0.1931]], grad_fn=<SliceBackward>))

# %%
patience = 10
n_epochs = 1000

model = DNN()

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.001, momentum=0.9)
early_stopping = EarlyStopping(patience=patience)
trainloader, validloader, testloader = prepare_dnn_dataloader(X_train, X_valid, X_test, y_train, y_valid, y_test)

trainer = DLTrainer(model, trainloader, validloader, testloader, criterion, optimizer, early_stopping, n_epochs, patience)
trainer.train()
# Out:
# [0/1000] train_loss: 2.18685 valid_loss: 2.14128 train_accuracy: 0.13176 valid_accuracy: 0.14199
# [1/1000] train_loss: 2.12395 valid_loss: 2.06689 train_accuracy: 0.17703 valid_accuracy: 0.20081
# [2/1000] train_loss: 2.04897 valid_loss: 1.98384 train_accuracy: 0.22770 valid_accuracy: 0.27789
# [3/1000] train_loss: 1.96568 valid_loss: 1.89679 train_accuracy: 0.29662 valid_accuracy: 0.37525
# [4/1000] train_loss: 1.88097 valid_loss: 1.80704 train_accuracy: 0.35473 valid_accuracy: 0.48479
train_accuracy: 0.99932 valid_accuracy: 0.99797
# EarlyStopping counter: 2 out of 10
# [344/1000] train_loss: 0.00663 valid_loss: 0.01939 train_accuracy: 0.99865 valid_accuracy: 0.99797
# EarlyStopping counter: 3 out of 10
# [345/1000] train_loss: 0.00864 valid_loss: 0.01999 train_accuracy: 0.99865 valid_accuracy: 0.99797
# EarlyStopping counter: 4 out of 10
# [346/1000] train_loss: 0.00875 valid_loss: 0.01919 train_accuracy: 0.99662 valid_accuracy: 0.99797
# [347/1000] train_loss: 0.00658 valid_loss: 0.01928 train_accuracy: 0.99932 valid_accuracy: 0.99797
# EarlyStopping counter: 1 out of 10
# [348/1000] train_loss: 0.00533 valid_loss: 0.01928 train_accuracy: 1.00000 valid_accuracy: 0.99797
# EarlyStopping counter: 2 out of 10
# [349/1000] train_loss: 0.00561 valid_loss: 0.01933 train_accuracy: 1.00000 valid_accuracy: 0.99797
# EarlyStopping counter: 3 out of 10
# [350/1000] train_loss: 0.00736 valid_loss: 0.01936 train_accuracy: 0.99932 valid_accuracy: 0.99797
# EarlyStopping counter: 4 out of 10
# [351/1000] train_loss: 0.00911 valid_loss: 0.01914 train_accuracy: 0.99865 valid_accuracy: 0.99797
# [352/1000] train_loss: 0.00587 valid_loss: 0.01926 train_accuracy: 0.99932 valid_accuracy: 0.99797
# EarlyStopping counter: 1 out of 10
# [353/1000] train_loss: 0.00656 valid_loss: 0.01916 train_accuracy: 0.99932 valid_accuracy: 0.99797
# EarlyStopping counter: 2 out of 10
# [354/1000] train_loss: 0.00772 valid_loss: 0.01900 train_accuracy: 0.99932 valid_accuracy: 0.99797
# [355/1000] train_loss: 0.00587 valid_loss: 0.01892 train_accuracy: 0.99932 valid_accuracy: 0.99797
# [356/1000] train_loss: 0.00591 valid_loss: 0.01895 train_accuracy: 1.00000 valid_accuracy: 0.99797
# EarlyStopping counter: 1 out of 10
# [357/1000] train_loss: 0.00508 valid_loss: 0.01895 train_accuracy: 1.00000 valid_accuracy: 0.99797
# EarlyStopping counter: 2 out of 10
# [358/1000] train_loss: 0.00703 valid_loss: 0.01902 train_accuracy: 0.99932 valid_accuracy: 0.99797
# EarlyStopping counter: 3 out of 10
# [359/1000] train_loss: 0.00540 valid_loss: 0.01987 train_accuracy: 0.99932 valid_accuracy: 0.99797
# EarlyStopping counter: 4 out of 10
# [360/1000] train_loss: 0.00651 valid_loss: 0.01895 train_accuracy: 1.00000 valid_accuracy: 0.99797
# EarlyStopping counter: 5 out of 10
# [361/1000] train_loss: 0.00938 valid_loss: 0.01979 train_accuracy: 0.99865 valid_accuracy: 0.99797
# EarlyStopping counter: 6 out of 10
# [362/1000] train_loss: 0.00583 valid_loss: 0.01907 train_accuracy: 1.00000 valid_accuracy: 0.99797
# EarlyStopping counter: 7 out of 10
# [363/1000] train_loss: 0.00688 valid_loss: 0.01898 train_accuracy: 1.00000 valid_accuracy: 0.99797
# EarlyStopping counter: 8 out of 10
# [364/1000] train_loss: 0.00554 valid_loss: 0.01895 train_accuracy: 1.00000 valid_accuracy: 0.99797
# EarlyStopping counter: 9 out of 10
# [365/1000] train_loss: 0.00507 valid_loss: 0.01901 train_accuracy: 1.00000 valid_accuracy: 0.99797
# EarlyStopping counter: 10 out of 10

# %%
dnn_valid_accuracy, dnn_valid_prediction = trainer.evaluate(validloader)
dnn_test_accuracy, dnn_test_prediction = trainer.evaluate(testloader)
print(dnn_valid_accuracy, dnn_test_accuracy)
# Out:
# 0.9979716024340771 0.9979757085020243

# %%
cnf_matrix = confusion_matrix(*dnn_test_prediction)
np.set_printoptions(precision=2)

# Plot non-normalized confusion matrix
plt.figure(figsize=(15,8))
plot_confusion_matrix(cnf_matrix, classes=activities, title='DNN Testing Confusion Matrix Without Normalization')

# Plot normalized confusion matrix
plt.figure(figsize=(15,8))
plot_confusion_matrix(cnf_matrix, classes=activities, normalize=True, title='DNN Testing Normalized Confusion Matrix')

plt.show()
# Out:
# Confusion Matrix Without Normalization
# Normalized Confusion Matrix

# %%
avg_train_losses, avg_valid_losses, train_accuracies, valid_accuracies = trainer.show_evaluation()
plot_avg_loss_per_epoch(avg_train_losses, avg_valid_losses)
plot_accuracy_per_epoch(train_accuracies, valid_accuracies)

# %%
performance_df = pd.DataFrame({
    'model': ["SVC", "DNN", "CNN"], 
    'valid_acc': [svc_valid_accuracy, dnn_valid_accuracy, cnn_valid_accuracy], 
    'test_acc': [svc_test_accuracy, dnn_test_accuracy, cnn_test_accuracy], 
})

performance_df
# Out:
#   model  valid_acc  test_acc
# 0   SVC   0.998985  1.000000
# 1   DNN   0.997972  0.997976
# 2   CNN   0.951318  0.959514
